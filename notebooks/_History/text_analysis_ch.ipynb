# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from transformers import BertTokenizer, BertModel, pipeline
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import ast
import re

# %% [markdown]
# Import data

# %%
file_path = r'.\..\data\data_clean\user_clean_data_ecommerce.csv'  # Update this with your file path
df_user = pd.read_csv(file_path)

# %%
df_user['cleaned_text'][0]
# Out:
# 'this spray is really nice. it smells really good, goes on really fine, and does the trick. i will say it feels like you need a lot of it though to get the texture i want. i have a lot of hair, medium thickness. i am comparing to other brands with yucky chemicals so im gonna stick with this. try it!'

# %%
df_user.head(5)
# Out:
#    rating                               review_title
# 0       5  Such a lovely scent but not overpowering.  \
# 1       4     Works great but smells a little weird.
# 2       5                                       Yes!
# 3       1                          Synthetic feeling
# 4       5                                         A+
#
#                                          text_review user_images  product_ID
# 0  This spray is really nice. It smells really go...          []  B00YQ6X8EO  \
# 1  This product does what I need it to do, I just...          []  B081TJ8YS3
# 2                          Smells good, feels great!          []  B07PNNCSP9
# 3                                     Felt synthetic          []  B09JS339BZ
# 4                                            Love it          []  B08BZ63GMJ
#
#     parent_ID                       user_ID                timestamp
# 0  B00YQ6X8EO  AGKHLEW2SOWHNMFQIJGBECAF7INQ  2020-05-05 14:08:48.923  \
# 1  B081TJ8YS3  AGKHLEW2SOWHNMFQIJGBECAF7INQ  2020-05-04 18:10:55.070
# 2  B097R46CSY  AE74DYR3QUGVPZJ3P7RFWBGIX7XQ  2020-05-16 21:41:06.052
# 3  B09JS339BZ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  2022-01-28 18:13:50.220
# 4  B08BZ63GMJ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  2020-12-30 10:02:43.534
#
#    helpful_review_vote  user_purchase_verification  year
# 0                    0                           1  2020  \
# 1                    1                           1  2020
# 2                    2                           1  2020
# 3                    0                           1  2022
# 4                    0                           1  2020
#
#                                         cleaned_text
# 0  this spray is really nice. it smells really go...
# 1  this product does what i need it to do, i just...
# 2                          smells good, feels great!
# 3                                     felt synthetic
# 4                                            love it

# %%
df_user.dropna(inplace=True)
df_user.shape
# Out:
# (692536, 12)

# %%
df_user['text_length'] = df_user['cleaned_text'].apply(len)  # Create a new column with text lengths

# Find the max and average text length
max_length = df_user['text_length'].max()
average_length = df_user['text_length'].mean()

print(f'Max text length (characters): {max_length}')
print(f'Average text length (characters): {average_length}')
# Out:
# Max text length (characters): 14692
# Average text length (characters): 170.48680357411024

# %% [markdown]
# Split the dataset

# %%
train_data, test_data = train_test_split(df_user, test_size=0.2, random_state=42)

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (554028, 13)
# (138508, 13)

# %% [markdown]
# Create the embeddings for the first 50 000 rows of the training dataset:

# %%
train_subset_data_01 = train_data[:50000].copy()

# %%
train_subset_data_unique_users = train_subset_data_01.user_ID.nunique()
train_subset_data_unique_users
# Out:
# 49334

# %% [markdown]
# ### Embeddings with BERT

# %% [markdown]
# * BertTokenizer:
# This is a tokenizer class from the transformers library provided by Hugging Face. It converts raw text into token IDs that a BERT model can process.
# BERT base uncased:
# "Base": Refers to the smaller version of BERT with 12 layers, 768 hidden units, and 110 million parameters.

# %%
# Check if a CUDA-compatible GPU is available on your system. "cuda:0" refers to the first GPU on the system (if there are multiple GPUs). If no GPU is available, device defaults to "cpu".
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Load the tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# c:\Users\Marcelina\Documents\neuefische\github\Capstone-Project-Recommender-System\.venv\Lib\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# Move the model to the GPU
model.to(device)
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %% [markdown]
# ### Old funciton for creating the embeddings:

# %%
# # Function to get BERT embeddings
# def get_bert_embeddings(text):
#     # Tokenize input text
#     inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512) # for now I'm gonna keep 512 (so it is max that BERT can take, because some sentences are very long)
    
#     # Move input tensors to the same device as the model (GPU or CPU)
#     inputs = {key: value.to(device) for key, value in inputs.items()}
    
#     # Forward pass through the model
#     outputs = model(**inputs)
    
#     # Get the embeddings (mean of the last hidden state)
#     return outputs.last_hidden_state.mean(dim=1).squeeze().detach().cpu().numpy()  # Move the result back to CPU if needed

# %% [markdown]
# ### Updated function by chunking for long text:

# %%
# Updated function to get BERT embeddings with chunking
def get_bert_embeddings(text):
    """
    Generates BERT embeddings for a given text, with support for chunking if the text is longer than 512 tokens.
    """
    # Tokenize the input text into subwords
    tokens = tokenizer.tokenize(text)  # Tokenize into subwords
    max_length = 512  # Maximum token length BERT can handle
    overlap = 50      # Overlap between chunks for better context continuity

    # If the text is short, process it directly
    if len(tokens) <= max_length:
        # Tokenize, truncate, and pad
        inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=max_length)
        
        # Move inputs to the same device as the model
        inputs = {key: value.to(device) for key, value in inputs.items()}
        
        # Forward pass through the model
        outputs = model(**inputs)
        
        # Get the embeddings (mean of the last hidden state)
        return outputs.last_hidden_state.mean(dim=1).squeeze().detach().cpu().numpy()

    # For long texts, split into chunks
    chunks = []
    for i in range(0, len(tokens), max_length - overlap):
        # Create a chunk of tokens with overlap
        chunk = tokens[i:i + max_length]
        # Convert tokens back to string format
        chunk_text = tokenizer.convert_tokens_to_string(chunk)
        
        # Tokenize, truncate, and pad the chunk
        inputs = tokenizer(chunk_text, return_tensors='pt', truncation=True, padding=True, max_length=max_length)
        
        # Move inputs to the same device as the model
        inputs = {key: value.to(device) for key, value in inputs.items()}
        
        # Forward pass through the model
        outputs = model(**inputs)
        
        # Get the embeddings (mean of the last hidden state for this chunk)
        chunk_embedding = outputs.last_hidden_state.mean(dim=1).squeeze().detach().cpu().numpy()
        chunks.append(chunk_embedding)
    
    # Aggregate chunk embeddings (mean pooling across all chunks)
    final_embedding = sum(chunks) / len(chunks)  # Average embeddings across chunks
    return final_embedding

# %%
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# ### Creating embeddings with BERT - run for the selected data

# %% [markdown]
# * Generating embeddings for the user's review with BERT,
# * From each cell with review text data, a vector of 768 dimensions will be generated and stored in a cell, in a column called 'embeddings',
# * Generated embeddings will be transformed from the lists of dimenstions into separated columns (one column per dimension) - therefore 768 columns will be created.

# %%
train_subset_data_01['embeddings'] = train_subset_data_01['cleaned_text'].apply(get_bert_embeddings)

# test_data['embeddings'] = test_data['cleaned_text'].apply(get_bert_embeddings)

# %%
# Verify if the column with 'embeddings' was created:
train_subset_data_01.head(2)
# Out:
#         rating                                       review_title
# 308320       3               Looks great but not practical for me  \
# 41091        4  This stuff is pretty interesting. I'm enjoying...
#
#                                               text_review
# 308320  [[VIDEOID:c9f78d09ec648d2bdc92f5ad9698e698]] T...  \
# 41091   This stuff is pretty interesting. I'm enjoying...
#
#                                               user_images  product_ID
# 308320  [{'small_image_url': 'https://m.media-amazon.c...  B09JNRPRKT  \
# 41091                                                  []  B0006O028U
#
#          parent_ID                       user_ID                timestamp
# 308320  B09JNRPRKT  AFOKWZIJI7K6Z6R4T7SSXRTWZNOQ  2022-02-22 19:21:19.256  \
# 41091   B0006O028U  AHQXHCQIGUBPQNJLQZNLBV7ESFPA  2015-01-04 00:21:08.000
#
#         helpful_review_vote  user_purchase_verification  year
# 308320                    0                           0  2022  \
# 41091                     1                           1  2015
#
#                                              cleaned_text  text_length
# 308320  videoidcfdecdbdcfade the look of this is very ...          751  \
# 41091   this stuff is pretty interesting im enjoying t...          109
#
#                                                embeddings
# 308320  [-0.33231324, 0.0543172, 0.4494611, 0.07581194...
# 41091   [0.049274728, 0.12549251, 0.12806682, 0.248745...

# %%
# From the lists of embeddings generate an array:
train_subset_data_stack = np.stack(train_subset_data_01['embeddings'].values)

# %%
train_subset_data_stack
# Out:
# array([[-0.33231324,  0.0543172 ,  0.4494611 , ..., -0.21085577,
#          0.05723506,  0.13091712],
#        [ 0.04927473,  0.12549251,  0.12806682, ..., -0.23682863,
#         -0.08841495, -0.03180593],
#        [-0.100202  ,  0.00652486,  0.3701543 , ..., -0.37329656,
#         -0.02400355,  0.27764842],
#        ...,
#        [ 0.10768944, -0.30886057,  0.5483214 , ..., -0.4442686 ,
#          0.0786995 , -0.23316805],
#        [-0.05036072, -0.18728136,  0.4251778 , ..., -0.37866172,
#         -0.20116793,  0.00801033],
#        [ 0.23054314,  0.20489387,  0.37537226, ..., -0.38489497,
#         -0.10621028, -0.05856288]], dtype=float32)

# %%
# Restrict to the first 50,000 rows:
train_data_50000 = train_data.iloc[:50000].copy()

# %%
# Create column names for embedding dimensions:
num_dimensions = train_subset_data_stack.shape[1]
embedding_columns_names = [f'dim_{i}' for i in range(num_dimensions)]

# %%
# Create the DataFrame of embeddings where each column contain one dimension of vector:
embedding_df = pd.DataFrame(train_subset_data_stack, columns=embedding_columns_names)

# %%
# Add generated embeddings to our original user data frame (the dataframe has only X number of rows, due to the splitting the original dataset):
df_user_embedding_01 = pd.concat([train_data_50000.reset_index(drop=True), embedding_df], axis=1)

# %%
df_user_embedding_01.shape
# Out:
# (50000, 781)

# %%
df_user_embedding_01.head(2)
# Out:
#    rating                                       review_title
# 0       3               Looks great but not practical for me  \
# 1       4  This stuff is pretty interesting. I'm enjoying...
#
#                                          text_review
# 0  [[VIDEOID:c9f78d09ec648d2bdc92f5ad9698e698]] T...  \
# 1  This stuff is pretty interesting. I'm enjoying...
#
#                                          user_images  product_ID   parent_ID
# 0  [{'small_image_url': 'https://m.media-amazon.c...  B09JNRPRKT  B09JNRPRKT  \
# 1                                                 []  B0006O028U  B0006O028U
#
#                         user_ID                timestamp  helpful_review_vote
# 0  AFOKWZIJI7K6Z6R4T7SSXRTWZNOQ  2022-02-22 19:21:19.256                    0  \
# 1  AHQXHCQIGUBPQNJLQZNLBV7ESFPA  2015-01-04 00:21:08.000                    1
#
#    user_purchase_verification  ...   dim_758  dim_759   dim_760   dim_761
# 0                           0  ... -0.067687 -0.20555  0.072889 -0.180823  \
# 1                           1  ... -0.303478  0.09138  0.122427 -0.186410
#
#     dim_762   dim_763   dim_764   dim_765   dim_766   dim_767
# 0  0.028919  0.010474 -0.138984 -0.210856  0.057235  0.130917
# 1 -0.027961 -0.255280  0.025104 -0.236829 -0.088415 -0.031806
#
# [2 rows x 781 columns]

# %%
# Save the original data frame with generated embeddings (new version with chunks):
df_user_embedding_01.to_csv(r'.\..\data\embeddings_output\df_user_embedding_fullsize_01_ch.csv', index=False)
# df_user_embedding_01.to_csv(r'.\..\data\embeddings_output\df_user_embedding_fullsize_01.csv', index=False)

# %% [markdown]
# ## Next steps - dimentionality reduction with PCA

# %% [markdown]
# * Similar steps but here the output is a final user dataframe with vectors of 300 dimensions (In the beginning I have chosen 10 only because that's what they have done in the artile but the variance dropped to 45%, so I set up for now 300 which gives ~95%.) We can always adjust it

# %%
# load the data - if not run just now:

# train_subset_data_ = pd.read_csv(r'.\..\data\embeddings_output\train_subset_embeddings_02.csv') #converters={"embeddings": str})

# %%
train_subset_data_01.head(2)
# Out:
#         rating                                       review_title
# 308320       3               Looks great but not practical for me  \
# 41091        4  This stuff is pretty interesting. I'm enjoying...
#
#                                               text_review
# 308320  [[VIDEOID:c9f78d09ec648d2bdc92f5ad9698e698]] T...  \
# 41091   This stuff is pretty interesting. I'm enjoying...
#
#                                               user_images  product_ID
# 308320  [{'small_image_url': 'https://m.media-amazon.c...  B09JNRPRKT  \
# 41091                                                  []  B0006O028U
#
#          parent_ID                       user_ID                timestamp
# 308320  B09JNRPRKT  AFOKWZIJI7K6Z6R4T7SSXRTWZNOQ  2022-02-22 19:21:19.256  \
# 41091   B0006O028U  AHQXHCQIGUBPQNJLQZNLBV7ESFPA  2015-01-04 00:21:08.000
#
#         helpful_review_vote  user_purchase_verification  year
# 308320                    0                           0  2022  \
# 41091                     1                           1  2015
#
#                                              cleaned_text  text_length
# 308320  videoidcfdecdbdcfade the look of this is very ...          751  \
# 41091   this stuff is pretty interesting im enjoying t...          109
#
#                                                embeddings
# 308320  [-0.33231324, 0.0543172, 0.4494611, 0.07581194...
# 41091   [0.049274728, 0.12549251, 0.12806682, 0.248745...

# %%
# pca = PCA(n_components=10) # I have tried with 10 as they speficied in the article but the variance dropped significantly to 45%. 
pca = PCA(n_components=300)
# train_subset_data = np.stack(train_subset_data_01['embeddings'].values)

# %%
train_subset_data_stack
# Out:
# array([[-0.33231324,  0.0543172 ,  0.4494611 , ..., -0.21085577,
#          0.05723506,  0.13091712],
#        [ 0.04927473,  0.12549251,  0.12806682, ..., -0.23682863,
#         -0.08841495, -0.03180593],
#        [-0.100202  ,  0.00652486,  0.3701543 , ..., -0.37329656,
#         -0.02400355,  0.27764842],
#        ...,
#        [ 0.10768944, -0.30886057,  0.5483214 , ..., -0.4442686 ,
#          0.0786995 , -0.23316805],
#        [-0.05036072, -0.18728136,  0.4251778 , ..., -0.37866172,
#         -0.20116793,  0.00801033],
#        [ 0.23054314,  0.20489387,  0.37537226, ..., -0.38489497,
#         -0.10621028, -0.05856288]], dtype=float32)

# %%
train_pca_subset = pca.fit_transform(train_subset_data_stack)
# test_pca = pca.transform(test_embeddings)

# %%
print(train_pca_subset.shape)
# Out:
# (50000, 300)

# %%
train_pca_subset
# Out:
# array([[-2.2205727 ,  0.8206018 , -1.1507324 , ..., -0.01921606,
#         -0.05422936,  0.02481445],
#        [-0.85250354,  0.78876585,  0.3090128 , ..., -0.08624018,
#          0.07009531, -0.09616351],
#        [-0.02784091,  0.02324333, -2.0407574 , ...,  0.02132656,
#         -0.06447431, -0.0215942 ],
#        ...,
#        [-1.5288411 , -0.0258608 , -0.570478  , ..., -0.07366744,
#         -0.14109671,  0.07452551],
#        [-1.1219059 , -0.31601486, -1.5046704 , ...,  0.0679103 ,
#          0.05569949,  0.0265916 ],
#        [ 0.43417406, -0.77137023,  0.14073612, ..., -0.15397538,
#          0.01573911, -0.05586669]], dtype=float32)

# %% [markdown]
# Create a dataframe with UserID and embedding dimensions columns:

# %%
# Create column names for embedding dimensions
num_dimensions = train_pca_subset.shape[1]
embedding_columns_PCA = [f'dim_{i}' for i in range(num_dimensions)]

# %%
embedding_df_PCA = pd.DataFrame(train_pca_subset, columns=embedding_columns_PCA)

# %%
final_df_user_PCA = pd.concat([train_data_50000.reset_index(drop=True), embedding_df_PCA], axis=1)

# %%
# Save PCA version witch 'chunk' text modification (added _ch in a name):
final_df_user_PCA.to_csv(r'.\..\data\embeddings_dim_reduction\df_final_user_PCA_ch.csv', index=False)
# final_df_user_PCA.to_csv(r'.\..\data\embeddings_dim_reduction\df_final_user_PCA.csv', index=False)

# %%
final_df_user_PCA.head(5)
# Out:
#    rating                                       review_title
# 0       3               Looks great but not practical for me  \
# 1       4  This stuff is pretty interesting. I'm enjoying...
# 2       1                 Every negative review here is true
# 3       4                                             Simple
# 4       4                                      Good Clip Ins
#
#                                          text_review
# 0  [[VIDEOID:c9f78d09ec648d2bdc92f5ad9698e698]] T...  \
# 1  This stuff is pretty interesting. I'm enjoying...
# 2  Too big and strangely shaped. Can’t use for po...
# 3  These are okay they give your lips a little ti...
# 4  I used these clip ins on a recent 5-day trip a...
#
#                                          user_images  product_ID   parent_ID
# 0  [{'small_image_url': 'https://m.media-amazon.c...  B09JNRPRKT  B09JNRPRKT  \
# 1                                                 []  B0006O028U  B0006O028U
# 2                                                 []  B08YJY6QXX  B08YJY6QXX
# 3                                                 []  B09F74KLTZ  B09F74KLTZ
# 4                                                 []  B07FNPN49W  B07FNPN49W
#
#                         user_ID                timestamp  helpful_review_vote
# 0  AFOKWZIJI7K6Z6R4T7SSXRTWZNOQ  2022-02-22 19:21:19.256                    0  \
# 1  AHQXHCQIGUBPQNJLQZNLBV7ESFPA  2015-01-04 00:21:08.000                    1
# 2  AGC3FCMCABBZEG5LLFG2AZSFGLQA  2022-02-21 18:05:21.190                    2
# 3  AFIV7RJS375WQLJNNF7OPBLGIHOQ  2021-10-04 17:17:35.117                    0
# 4  AHNQJWY7VTX2GIHBKNGD7MS2XMUA  2018-09-06 17:50:02.665                    0
#
#    user_purchase_verification  ...   dim_290   dim_291   dim_292   dim_293
# 0                           0  ...  0.023845  0.057696  0.002842  0.000553  \
# 1                           1  ... -0.094351  0.018936 -0.104710 -0.104361
# 2                           1  ...  0.050436  0.040444 -0.043215  0.171432
# 3                           0  ...  0.022718 -0.027460  0.217338 -0.056780
# 4                           1  ...  0.080945 -0.065782  0.117690  0.131351
#
#     dim_294   dim_295   dim_296   dim_297   dim_298   dim_299
# 0 -0.082094  0.000306 -0.032792 -0.019216 -0.054229  0.024814
# 1  0.007777  0.098594 -0.002512 -0.086240  0.070095 -0.096164
# 2 -0.053496  0.150505 -0.002388  0.021327 -0.064474 -0.021594
# 3  0.092378 -0.008888  0.106759 -0.007923  0.006500  0.012411
# 4 -0.188997  0.006255  0.102548  0.056575 -0.051365  0.026357
#
# [5 rows x 313 columns]

# %%
similarity_matrix = cosine_similarity(train_pca_subset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 similarity_matrix = cosine_similarity(train_pca_subset)
#
# NameError: name 'train_pca_subset' is not defined

# %%
similarity_matrix[0][1]
# Out:
# 0.10673274

# %%
similarity = cosine_similarity([train_pca_subset[12]], [train_pca_subset[10]])
print("Similarity:", similarity[0][0])
# Out:
# Similarity: 0.30784366

# %% [markdown]
# ## PCA - Variance analysis

# %% [markdown]
# * Verify if the size of reduced embeddings is big enough to still keep the meaning of the textual data

# %% [markdown]
# Original embeddings:

# %%
user_embeddings_original = pd.read_csv(r'.\..\data\embeddings_output\df_user_embedding_fullsize_01_ch.csv')
user_embeddings_original.head(2)
# Out:
#    rating        review_title
# 0       4  good for the price  \
# 1       5          Five Stars
#
#                                          text_review user_images  product_ID
# 0  I only got 19 and 1 was missing a jewel and I ...          []  B00L62HMQG  \
# 1                  Really great blush for the price.          []  B00BMW24TU
#
#     parent_ID                       user_ID                timestamp
# 0  B00L62HMQG  AF3BP6BP64XWBLQ6GTZKASW33EEQ  2015-08-05 09:04:21.000  \
# 1  B00BMW24TU  AGNRWZQ345LQCQ2M2X67JHJPK6OA  2015-08-22 01:13:49.000
#
#    helpful_review_vote  user_purchase_verification  ...   dim_758   dim_759
# 0                    0                           1  ... -0.130055 -0.093996  \
# 1                    0                           1  ... -0.115743 -0.310988
#
#     dim_760   dim_761   dim_762   dim_763   dim_764   dim_765   dim_766
# 0  0.183146 -0.123054 -0.168095  0.001715 -0.028300 -0.136207  0.255881  \
# 1 -0.029846 -0.399967  0.149936  0.052017 -0.098667 -0.185217  0.117753
#
#     dim_767
# 0 -0.052698
# 1 -0.354692
#
# [2 rows x 781 columns]

# %%
user_embeddings_original.shape
# Out:
# (50000, 781)

# %%
unique_values_user_original = user_embeddings_original.user_ID.nunique()
unique_values_user_original
# Out:
# 49334

# %%
original_embeddings = user_embeddings_original[[f"dim_{i}" for i in range(768)]]

# %%
# Fit PCA to the original embeddings
pca = PCA(n_components=300)
pca.fit(original_embeddings)

# Check explained variance
explained_variance = pca.explained_variance_ratio_
total_variance = sum(explained_variance)

print("Explained Variance Ratio for 300 Dimensions:", explained_variance)
print("Total Explained Variance Captured by 300 Dimensions:", total_variance)
# Out:
# Explained Variance Ratio for 300 Dimensions: [0.15770545 0.04569084 0.04178757 0.0338528  0.03102464 0.02787922
#  0.02636755 0.02194665 0.02034436 0.0183385  0.01677296 0.01598295
#  0.01471035 0.01364272 0.01254376 0.01161625 0.01046816 0.01018101
#  0.0099389  0.00890585 0.0086756  0.0080092  0.00779689 0.00759841
#  0.00722639 0.00686972 0.00682086 0.00650492 0.0063136  0.00610409
#  0.00603635 0.00575361 0.00541211 0.0052985  0.00505044 0.00496439
#  0.00490285 0.0046469  0.00454809 0.00427476 0.00419961 0.00404253
#  0.00397964 0.00389777 0.0037465  0.00370564 0.00361358 0.00351666
#  0.00347613 0.00337534 0.00336742 0.00329549 0.00314648 0.00312515
#  0.00297752 0.00290766 0.00289047 0.00285901 0.00279358 0.00277922
#  0.00272794 0.0026373  0.00260225 0.00255192 0.00245783 0.00243023
#  0.00236718 0.0023391  0.00229463 0.00223147 0.00219138 0.00214752
#  0.00213039 0.0020896  0.00206988 0.00203307 0.0020144  0.00195577
#  0.00191488 0.00186871 0.00184891 0.00182126 0.00179657 0.00174935
#  0.00173724 0.00171308 0.0017102  0.00167029 0.00166862 0.00162966
#  0.00159459 0.00157915 0.00156898 0.00155563 0.0015429  0.00150653
#  0.00149082 0.00145776 0.00145718 0.00143327 0.00142936 0.00140098
#  0.00138687 0.00137559 0.00137091 0.00133096 0.00131475 0.00130746
#  0.00129525 0.00127381 0.00125515 0.00124891 0.0012388  0.00121402
#  0.00119329 0.00118183 0.00117814 0.00115834 0.00114623 0.00113759
#  0.00111931 0.00109288 0.00108921 0.0010699  0.00105941 0.00105352
#  0.00104291 0.00103038 0.00102227 0.00101056 0.0010079  0.00097463
#  0.00097367 0.00096264 0.00095833 0.00094682 0.00094509 0.00092399
#  0.00091687 0.00091108 0.00090799 0.00089717 0.00088977 0.00088022
#  0.00087737 0.00086516 0.00086195 0.00085178 0.00084703 0.00083929
#  0.00082573 0.00081846 0.00080971 0.00079817 0.00079283 0.00078613
#  0.00077584 0.00076539 0.00075815 0.00074865 0.00074125 0.00074072
#  0.00073091 0.00072704 0.00071968 0.00071864 0.00070893 0.00070359
#  0.00070016 0.00069146 0.00068854 0.00068581 0.00068149 0.00067499
#  0.00066639 0.00066429 0.00065665 0.00064814 0.00064272 0.00064029
#  0.00063326 0.00062824 0.00061656 0.00061333 0.0006121  0.00060856
#  0.00060532 0.00059886 0.00059485 0.0005811  0.00057814 0.00057166
#  0.00056743 0.00055995 0.00055881 0.00055823 0.00054691 0.00054484
#  0.00054347 0.00054117 0.00053908 0.00053228 0.000528   0.00052648
#  0.00052243 0.00051772 0.00051568 0.00051002 0.00050584 0.00050353
#  0.000502   0.00050089 0.00049192 0.00049032 0.00048596 0.00048383
#  0.00048303 0.00047879 0.00047417 0.00046942 0.00046505 0.00046199
#  0.00046044 0.00045884 0.00045349 0.00044951 0.00044092 0.00043878
#  0.00043366 0.00043292 0.00043086 0.00042642 0.0004244  0.00042141
#  0.00041917 0.0004183  0.00041323 0.00040982 0.00040829 0.00040364
#  0.00040163 0.00040104 0.00039627 0.00039204 0.00038742 0.00038541
#  0.00038197 0.00037907 0.00037871 0.0003755  0.0003738  0.00037273
#  0.00036872 0.00036609 0.00036521 0.0003616  0.00036014 0.00035478
#  0.0003541  0.00035321 0.00034924 0.00034666 0.00034527 0.00034089
#  0.00033854 0.00033603 0.00033491 0.00033327 0.00033178 0.00032661
#  0.00032436 0.00032365 0.00032073 0.00031817 0.00031624 0.00031328
#  0.00031064 0.00031005 0.00030742 0.000306   0.00030206 0.00030072
#  0.00029863 0.00029436 0.00028998 0.00028869 0.00028662 0.00028373
#  0.00028108 0.00027866 0.00027595 0.00027403 0.00027289 0.0002709
#  0.00026966 0.00026564 0.00026472 0.00026213 0.00025949 0.00025841]
# Total Explained Variance Captured by 300 Dimensions: 0.9437859279557334

# %% [markdown]
# # Once all embeddings are calculated we can go to the next step (so far calculations are made only for the sample of 50000 rows of the training dataset)

# %% [markdown]
# ## Create User and Product Vectors

# %% [markdown]
# * Aggregating the embeddings to compute a single user vector per user_ID and single product vector per product_ID.
# * To create a vector for each user, you can average all the review embeddings corresponding to that user. This works because averaging retains a general sense of the user's overall preferences.
# * Similarly, you can aggregate the embeddings for each product. For example, average all the embeddings corresponding to each product ID.

# %%
# load the dataset of PCA embeddings: 
final_df_user_PCA = pd.read_csv(r'.\..\data\embeddings_dim_reduction\df_final_user_PCA_ch.csv')

# %%
# Verify the number of unique users:
unique_values_user = final_df_user_PCA.user_ID.nunique()
unique_values_user
# Out:
# 49334

# %%
final_df_user_PCA.head(5)
# Out:
#    rating                    review_title
# 0       4              good for the price  \
# 1       5                      Five Stars
# 2       5                            Good
# 3       5  Great Value and Easy to Use !!
# 4       5                       Best ever
#
#                                          text_review user_images  product_ID
# 0  I only got 19 and 1 was missing a jewel and I ...          []  B00L62HMQG  \
# 1                  Really great blush for the price.          []  B00BMW24TU
# 2                                          Very nice          []  B094VMYQJP
# 3  I bought these bottles to add my pre-mixed pai...          []  B0758V2K3K
# 4  This is the best curling iron I ever had in my...          []  B001MP0QH4
#
#     parent_ID                       user_ID                timestamp
# 0  B00L62HMQG  AF3BP6BP64XWBLQ6GTZKASW33EEQ  2015-08-05 09:04:21.000  \
# 1  B00BMW24TU  AGNRWZQ345LQCQ2M2X67JHJPK6OA  2015-08-22 01:13:49.000
# 2  B094VMYQJP  AGKNJHA77X4LVIXVP56MHF4C22SA  2021-11-11 06:12:08.453
# 3  B0758V2K3K  AFADUDWDAFJK7YSILOUBAHSR7I5Q  2022-03-06 21:20:40.790
# 4  B01N4885PD  AHHVPEX3YEH6Z6Q5PDIJY45SOLKQ  2019-12-06 17:24:50.705
#
#    helpful_review_vote  user_purchase_verification  ...   dim_290   dim_291
# 0                    0                           1  ...  0.023684 -0.200487  \
# 1                    0                           1  ... -0.117988  0.022417
# 2                    0                           1  ... -0.048496 -0.075755
# 3                    0                           1  ...  0.008855  0.045144
# 4                    9                           1  ... -0.122009  0.052409
#
#     dim_292   dim_293   dim_294   dim_295   dim_296   dim_297   dim_298
# 0 -0.199311 -0.138646  0.029778  0.006494 -0.068038  0.025784  0.145278  \
# 1  0.060439  0.083243 -0.167081 -0.018106 -0.091886 -0.027956 -0.079749
# 2  0.017430  0.068834  0.051646  0.043402 -0.035908  0.044530 -0.111660
# 3 -0.019571  0.043039 -0.053009  0.051053  0.041208 -0.015779 -0.011635
# 4 -0.013907  0.069467 -0.043739 -0.085013  0.055296 -0.097808 -0.022167
#
#     dim_299
# 0 -0.015662
# 1  0.010902
# 2 -0.062793
# 3  0.013147
# 4 -0.023810
#
# [5 rows x 313 columns]

# %% [markdown]
# Create a dataframe that stores all items that the user purchased, to remove those from the recommendations

# %%
user_item_df = final_df_user_PCA.groupby('user_ID')['product_ID'].apply(list).reset_index()
user_item_df
# Out:
#                             user_ID    product_ID
# 0      AE222BBOVZIF42YOOPNBXL4UUMYA  [B013HR1A92]
# 1      AE223UUOHC3V2XF4JOTTDDSBODSQ  [B06Y5Y3R5L]
# 2      AE225T2ZALMW2LGAWZGONMYD2VJA  [B09Y1BWYCR]
# 3      AE225THXPLSO5QQ3PHQP7SPETM2A  [B07RVPC6X5]
# 4      AE226AADLLWDPLLWOEGKUCBNZH4A  [B007MAJFD4]
# ...                             ...           ...
# 49329  AHZZOHEFU5EO466C2BAPPVV7CEJA  [B08PVXSM6Z]
# 49330  AHZZOMWUCOOYQWZUIK4QQPKQE46Q  [B08KHCMN8X]
# 49331  AHZZPMMB4Y5DHXAXOTBFALIKPU7A  [B09GFTS277]
# 49332  AHZZSYRRKQ4QAOTMYS5RHYWJU4HA  [B00BLWWY7S]
# 49333  AHZZYDN7XZXJRETMPWW4RRD4PS2Q  [B07FTD9XNJ]
#
# [49334 rows x 2 columns]

# %% [markdown]
# ### 1. Aggregate User Vectors

# %%
# Select relevant columns: user_ID and embedding dimensions
user_vector_cols = [f'dim_{i}' for i in range(300)]
df_user_vectors = final_df_user_PCA.groupby('user_ID')[user_vector_cols].mean().reset_index()

# Rename the columns to indicate these are user vectors:
df_user_vectors.columns = ['user_ID'] + [f'user_vec_{i}' for i in range(300)]

df_user_vectors.shape

# %%
df_user_vectors.head()
# Out:
#                         user_ID  user_vec_0  user_vec_1  user_vec_2
# 0  AE222BBOVZIF42YOOPNBXL4UUMYA    1.193942   -0.031829   -0.545995  \
# 1  AE223UUOHC3V2XF4JOTTDDSBODSQ    7.270741    0.962162    0.227079
# 2  AE225T2ZALMW2LGAWZGONMYD2VJA    0.174955   -0.948436    1.882202
# 3  AE225THXPLSO5QQ3PHQP7SPETM2A   -1.935537    0.112038   -0.131342
# 4  AE226AADLLWDPLLWOEGKUCBNZH4A   -1.642184    0.869897    0.106127
#
#    user_vec_3  user_vec_4  user_vec_5  user_vec_6  user_vec_7  user_vec_8
# 0    1.647325   -1.807717    0.085607   -1.147378    0.331433    1.707212  \
# 1   -1.170762    0.693367   -2.156547   -0.341253   -0.047256    0.562146
# 2   -0.447089   -0.092247    0.112225   -0.193614   -0.125204    0.054014
# 3    0.424573    0.312248   -0.921699   -0.190502   -0.187693    0.513127
# 4   -0.015727   -0.932361   -0.748179   -0.607914    0.023849   -0.454445
#
#    ...  user_vec_290  user_vec_291  user_vec_292  user_vec_293  user_vec_294
# 0  ...      0.152986      0.048130     -0.123529     -0.185242     -0.268880  \
# 1  ...     -0.077601      0.075907      0.050284      0.149839      0.057757
# 2  ...      0.191429      0.162861      0.145655      0.075837     -0.109375
# 3  ...     -0.038536      0.039262     -0.007145     -0.011664      0.028899
# 4  ...     -0.019929      0.009594      0.112430      0.026911      0.091934
#
#    user_vec_295  user_vec_296  user_vec_297  user_vec_298  user_vec_299
# 0      0.062162      0.003835     -0.081791     -0.077197     -0.119425
# 1      0.048207     -0.032500     -0.105583     -0.046921     -0.064304
# 2      0.035572      0.023073     -0.105869      0.081911     -0.139805
# 3     -0.078002     -0.131282     -0.067536      0.030160     -0.014879
# 4      0.016892     -0.052036     -0.014126     -0.083984      0.025487
#
# [5 rows x 301 columns]

# %%
# Save the vectors
df_user_vectors.to_csv(r'.\..\data\text_analysis\user_vectors\user_vectors_ch.csv', index=False)

# %% [markdown]
# ### 2. Aggregate Product Vectors

# %%
product_vector_cols = [f'dim_{i}' for i in range(300)]
df_product_vectors = final_df_user_PCA.groupby('product_ID')[product_vector_cols].mean().reset_index()

df_product_vectors.columns = ['product_ID'] + [f'product_vec_{i}' for i in range(300)]
df_product_vectors.shape
# Out:
# (25915, 301)

# %%
df_product_vectors.head()
# Out:
#    product_ID  product_vec_0  product_vec_1  product_vec_2  product_vec_3
# 0  0005946468       6.730880       0.135069       1.123490      -1.279470  \
# 1  069267599X      -0.525602       0.345588       1.282988      -0.358174
# 2  0816091846       0.029595       0.861594       0.458656      -0.143020
# 3  0977217213       3.834755       0.291670      -0.880154      -0.309399
# 4  1421790432      -1.453551       0.149348       1.918752      -0.578319
#
#    product_vec_4  product_vec_5  product_vec_6  product_vec_7  product_vec_8
# 0       0.912430      -1.771424      -0.112034       0.214289       0.129676  \
# 1      -0.505468      -0.233787      -0.778394       0.085404      -0.501695
# 2       0.075874      -0.613368      -1.103830      -0.114904      -0.403521
# 3       0.787637      -0.309833       0.748977      -0.470044       0.135276
# 4      -0.207081      -0.307189      -1.363799      -0.655058      -0.021827
#
#    ...  product_vec_290  product_vec_291  product_vec_292  product_vec_293
# 0  ...         0.063355         0.001758        -0.136104         0.019494  \
# 1  ...         0.017629        -0.023244        -0.071321        -0.105923
# 2  ...        -0.053765         0.016102         0.232078         0.120994
# 3  ...        -0.043916        -0.193804         0.018712         0.435845
# 4  ...        -0.019989        -0.017782         0.097501         0.073597
#
#    product_vec_294  product_vec_295  product_vec_296  product_vec_297
# 0         0.016054        -0.045845        -0.029626        -0.109935  \
# 1        -0.049329        -0.067786         0.009429        -0.019416
# 2         0.037491        -0.009946        -0.099035        -0.017921
# 3        -0.007382         0.115578         0.043922        -0.301531
# 4         0.113653        -0.119419        -0.181618         0.002024
#
#    product_vec_298  product_vec_299
# 0         0.105087         0.086668
# 1         0.064645         0.040169
# 2         0.088834         0.049036
# 3        -0.078577        -0.266278
# 4         0.007175        -0.008132
#
# [5 rows x 301 columns]

# %%
# Save product vectors
df_product_vectors.to_csv(r'.\..\data\text_analysis\product_vectors\product_vectors_ch.csv', index=False)

# %% [markdown]
# # Semantic Analysis

# %% [markdown]
# ## Compare Reviews - Similarity Research with COS Similarity

# %% [markdown]
# * Extract the user and product vectors.
# * Compute the cosine similarity between each user and all products.
# * Rank products for each user based on similarity scores.

# %%
# Extract user vectors
user_ids = df_user_vectors['user_ID'].values
user_vectors = df_user_vectors.iloc[:, 1:].values

# Extract product vectors
product_ids = df_product_vectors['product_ID'].values
product_vectors = df_product_vectors.iloc[:, 1:].values

# %%
print(f"Shape of User Vectors: {user_vectors.shape}")
print(f"Shape of Product Vectors: {product_vectors.shape}")
# Out:
# Shape of User Vectors: (49334, 300)
# Shape of Product Vectors: (25915, 300)

# %%
# Compute cosine similarity between all users and all products
cosine_similarities = cosine_similarity(user_vectors, product_vectors)

print(f"Cosine Similarity Matrix Shape: {cosine_similarities.shape}")
# Rows correspond to users, columns correspond to products
# Out:
# Cosine Similarity Matrix Shape: (49334, 25915)

# %%
def recommend_top_n_products_by_user_id(user_id, user_ids, similarity_matrix, product_ids, top_n=5):
    """
    Recommend top N products for a given user based on cosine similarity.

    Parameters:
    - user_index: Index of the user in the similarity matrix
    - similarity_matrix: Cosine similarity matrix (users x products)
    - product_ids: List of product IDs corresponding to columns in similarity matrix
    - top_n: Number of top recommendations to return

    Returns:
    - List of (product_id, similarity_score) tuples
    """

    # Find the index of the user_ID
    if user_id not in user_ids:
        raise ValueError(f"User ID '{user_id}' not found in the user data.")
    
    user_index = np.where(user_ids == user_id)[0][0]  # Locate the index of user_id
    
    # Get similarity scores for the user
    user_similarities = similarity_matrix[user_index]
    
    # Step 4: Retrieve the list of already purchased products for the user
    purchased_products = user_item_df.loc[user_item_df['user_ID'] == user_id, 'product_ID']
    if not purchased_products.empty:
        purchased_products = set(purchased_products.iloc[0])  # Convert to a set for faster lookups
    else:
        purchased_products = set()

    # Step 5: Sort product indices by similarity scores in descending order
    sorted_indices = user_similarities.argsort()[::-1]  # Sort in descending order
    
    # Step 6: Filter out already purchased products
    recommendations = []
    for i in sorted_indices:
        product = product_ids[i]
        if product not in purchased_products:
            recommendations.append((product, user_similarities[i]))
        if len(recommendations) >= top_n:  # Stop when we have enough recommendations
            break
    
    return recommendations
# Example usage: Get recommendations for a specific user_ID
user_id_input = "AGGS22XG63AQTYBR3APBQA25HAYQ"  # Replace with any valid user_ID
top_n = 5

try:
    recommendations = recommend_top_n_products_by_user_id(user_id_input, user_ids, cosine_similarities, product_ids, top_n)
    print(f"Top-{top_n} Recommendations for User '{user_id_input}':")
    for product_id, score in recommendations:
        print(f"Product ID: {product_id}, Similarity Score: {score:.4f}")
except ValueError as e:
    print(e)
# Out:
# Top-5 Recommendations for User 'AGGS22XG63AQTYBR3APBQA25HAYQ':
# Product ID: B0B8Q3WTGP, Similarity Score: 0.6704
# Product ID: B01N41MYDC, Similarity Score: 0.6363
# Product ID: B08GWZKPPL, Similarity Score: 0.6258
# Product ID: B00069Q306, Similarity Score: 0.6242
# Product ID: B00XFGNPE4, Similarity Score: 0.6240

# %%
duplicate_user_ids = final_df_user_PCA['user_ID'][final_df_user_PCA['user_ID'].duplicated()].unique()
duplicate_user_ids
# Out:
# array(['AEZP6Z2C5AVQDZAJECQYZWQRNG3Q', 'AGGS22XG63AQTYBR3APBQA25HAYQ',
#        'AERDBP26RSGAGWWORPE6MQADNR2Q', 'AHVQR7U4PJ7VTG36DQMRSIHK7O6A',
#        'AFWVN52MRBWOTIK7UGXBWGOY4HBA', 'AHGQDSOBAIVAAKJFIVEGS344MSXA',
#        'AFPBV45MYM2HLBT2AH2JJ3FUADUQ', 'AHY2TURQPNIDXZGH2CMQLZ343YMQ',
#        'AHYOSWORVZFXM5QMRIAW3JTTFFIQ', 'AE5UWYX65MMYGGAHNP2UJONMRRXQ',
#        'AGI627XXI5DPCMEHBJKZU7WPQK6Q', 'AECQQBG6YRYCOJL2NCB2H3V6LD6Q',
#        'AE5IMGWRBJA7JQFBQTBK25HDYGVA', 'AG7JCEMC64AM7JPATDVGP6YZOTXA',
#        'AH6YII7DVISC5SBK62F5POULSI6A', 'AGOYO44Q3YUXRQ5N2YZRVSYTYEWQ',
#        'AFRJTKBKVBAHKPIV3OIYAGS6AFRQ', 'AGZUJTI7A3JFKB4FP5JOH6NVAJIQ_1',
#        'AG6PJGM3ZTNOH6RY4G6GKPCMHT5A', 'AGFTTUBGWZRDVULR3NRZYQNS5IHQ',
#        'AF3XZ6UDOR4V6SMVUKWQ3IZ3JO5Q', 'AEUEEZXVXRWGO5LWPIS25R2LCKKA',
#        'AG73BVBKUOH22USSFJA5ZWL7AKXA', 'AGMSR3KN2YEMEKFWWXEPIZMJKYAA',
#        'AGCAJ2SSP4VUHIX3CHMEGFEYPD4Q', 'AFXF3EGQTQDXMRLDWFU7UBFQZB7Q',
#        'AGBLLVBF7XRK6LIZW52ATUFQBGQA', 'AEAXAJACFMXIAAH4WOHRMXPSZWFA',
#        'AE6KYNMAM7T67K2IL4OP76JXAGJA', 'AFW43SS5XKIABTMZDWWILMDDXC7Q',
#        'AECADZLPUNH3BDNACLFF7PSHN5MQ', 'AEMP3A7IKW37CMWFXNKXWW6HGJHA_1',
#        'AFDYIK3FNPY2JFBQYUWC6GSBMIRQ_2', 'AFPQJSBCMEKL3PT54KPROBQ2TAXA',
#        'AEOK4TQIKGO23SJKZ6PW4FETNNDA_1', 'AE5BPLD2H5KSX2O7MMOXKB4VGDRQ',
#        'AEBD4EQFW4THUDUVAETCYTEDJU6Q', 'AEHWKRPNWNMOAJSMO2F6O7RFRTNA',
#        'AHVBF3BZ54INZXL5OYREEBLGSDEA', 'AEIGG3Z7NQLYWRT3I7OZ3KO74D3A',
#        'AE3PLZHW6NXWBMZ76TDVFQG2MJFA', 'AG4VBFTUDATHNYMJB5NBB22CYFXQ',
#        'AGCGQWDEGSGIIT7AZZ7RGY5ZU74Q', 'AGTQTJDD223DGS2IWI6GNPFZHTPA',
#        'AFPFMLP6HINFGHRCK5ZOWCVBBO7Q', 'AEW7Y6PFYTT426AA7EJPW5JYEZ3A',
#        'AGFLDIUYV2PKF5Q7IEMULR52GW2Q', 'AEOOYP2S6EEORPRUAUDURUOCBS4Q',
#        'AHTS5HKKNQU7RVZ6TP7SDVRASYWQ', 'AEVFWS7JFEKHYDZKH4SI5YDSNGJQ_1',
#        'AHJ5LXYWWWIGTONRRE324QLU6UCA', 'AH2IUF6ZS2UFW6RZWS3WMZY5AG2Q',
#        'AFW7TRFFU2UWX4GLDF7UMOTJJ6IA', 'AHAPXOC2Q6GVH6KRZDPGMGPX5LNQ',
#        'AHG5KKQMMZJA46LDH73IZ4QUHYXA', 'AHJANRT2I3BFO5HAOAZEZJMB4OHA',
#        'AF6SM2ESLD534XWS7P6PFSL257CA', 'AHNIV2J4KWXNRTPKHA2CCIT3POGA',
#        'AGWDYYVVWM3DC3CASUZKXK67G6IA', 'AEFLR7CMNDLXWNH4CC6TVU4EEYXQ',
#        'AHPGHDFIU3BUB3RQBP56RQQA7W4Q', 'AEC6IZVI2NGFBCIYVD4X5MDGB6DQ_2',
#        'AHBDPVXHGNIRMIGLCRCABCOLFJTA', 'AFF42FVZXV65X2Q3FC5IULATTRGA',
#        'AHG2MNR6FB76P36LLKEZJVDNIWUQ', 'AE5ESL52LWWBJTSFOAXSFZA3XCGQ',
#        'AGBXLQMTTFVKAUABEGPNODQH7BHQ', 'AFQQQ5LGNSQUEBGDCYBAZZE5T3DA',
#        'AHXURPXHWYEKA672S37CU2ZCMOYQ', 'AE7NL5T6FXV6RHIW7EKCXT7VLABA',
#        'AEEZXPZEMQ4DIQKT2LW5J6TPXAWQ', 'AFGYRMSLRWWACGCN7BWO4NLJ563Q',
#        'AHBFC446AIQBMLC3U4SV6YJJERPQ', 'AGQIUTI7M4XUGCRV6E66FAOCX5PQ',
#        'AFEFGCMPJMEYF27LKD4IVKLISWAQ', 'AFHDDNDKEM4GBEYWPJ3NAF7MJEPQ',
#        'AE2WMFLNQAV4U5O5XL7AU7LYSL3Q', 'AHEWKNQ6ZTMR5YIQ4RXE5EJKIQ3Q',
#        'AEPPO3HMAFNZS4JJZ6JLN7A7AWFA', 'AHJCM3JRBF4KIY35BR5CJIL63WTA',
#        'AEAW2PLU3FEEFD3CEDDQTGB6AYTQ', 'AGRNGOIYWIYDD3WGEMNOEM7222MQ',
#        'AGKZA457QG3WKFUCUR2DXAK4XX3A', 'AEE4M36AZAKURLEYGV23TM3BE7OQ',
#        'AEJU3Z6HDAERETMYI2CXBQVPPDFA', 'AEY26SNCXZQ6YG4GSJI7CDMZV32Q',
#        'AFVOCPD6U6SEVEIWAPY7AAQTHK3A', 'AEJFHW6P566WXVFWTRNG4CE4M5JA',
#        'AFKWXVOODG3OENPBTP27V77KJIGQ', 'AGB5SLLK7AXMK5MYIGZ74DAAMZBA',
#        'AF2EJBZAFNBGUOIJ5GDPTARQGZWQ', 'AGNGL5CYYEB5CZLIRD5F5XSX2H4A',
#        'AE3LUVAAITFJIUTWBMRPHDQOCOFQ', 'AFNXNDUCRDLIJ7Y3KVR45ZCFW35Q',
#        'AE3PTBG5IFFBHHSYYM4TLQCSZVWQ', 'AHBWH2LBU3NFLD46GKJKIBAHKXEQ',
#        'AE6ZJKZBZ4BKC3LTPAI6G6WIYK2A', 'AGI6HCRPSPJA6LIBES5WJSNJZHSQ',
#        'AGCSHQRXX6N4TA2ZNC5BZHQ6PQYA', 'AF5C7E2ABOK2QGIA5GWAFJ6UQBYQ',
#        'AFGOKVANBXYFEXI5U3P3PFBHVNDQ', 'AGWKGRP7FERG6XL7O222DCC5VYTQ',
#        'AGOLMT3QETKYNESRYKBA6D7XXS7A', 'AGC7QCUXJISMEA6RKUGWBKYFA3EA',
#        'AEMLOKBJ63LBLQ5CU44J5TWQRGZQ', 'AEEPKLM36LPIRKTPNKB4GCGZAZEQ',
#        'AFGGRGHGHSFKMZASFBYFRHBBEOPA', 'AEJ2R5TNOAQZ254BCMS2B76KFBJQ',
#        'AH2UY7SSMEI63JC2BLLF56F6T73Q', 'AEWT5SHY3ZNHHFZRAIBRVSPZH2TA',
#        'AHZUBYEWJ22S5ARCPTYRKDRWXERA', 'AGJ2ZFDUT6CO3JP7KO53WHEYEGKQ',
#        'AEKZVUWFM4AVGF2JGBGPVRKKIUHA', 'AFEIS4GXIRTGLJ4ATDII53GAUBWA',
#        'AEYVPPWR4CIKWX4BGYKCBCDL2CZQ', 'AES3YWD3ONJOUDRWFIV2ZO44QDAQ',
#        'AH5ONINJRNZ674DXUMV4RMYIFYVQ', 'AHDVSLWHSORYGG3S5QZMVDFNOXUQ',
#        'AFHS73BXD56CMJPUBNQ7QUEAL4YA', 'AHQN4YVZHLK7J7D6WYG6I3V5OUTQ',
#        'AFPDO2IZIFDPVBJQXBH6DJY24ISA', 'AEODUUL6REW3PW2ZGFREKGWBYUZA',
#        'AGRCJJAVFC5PAFTPISKP2TCLDBEA', 'AFRBHOIQP232WWZ3JQTGPBVTPE7A',
#        'AF3K7ALDAMTKR4LEHWQBN7MAUJBQ', 'AH2M2JDJDLEELUZZK26TQWCRXDUQ',
#        'AGD25H7BIT2JUXSIOPYCYB23J3ZQ', 'AFLRDMHZMDTTCAR5OBZCFNIHGMRQ',
#        'AGYGKQXQXKCKBTGRONBLUWLXLW4A', 'AFLN7WKIOMGBTYYJ2B4OJGTCLAJQ',
#        'AGMUSW4TCZGANHTV6UTAUEM2GS3Q', 'AGIWI2O4WGMLMYVSJJE7DTCMJTBQ',
#        'AF266FX67WFI3LIGFU7KU7MQC74Q', 'AEJUJLXYEFXUHS4YQTETBDYWZUXA',
#        'AECYBCDHDJJGZAYVXXDPPZA3ST3A', 'AHYAHSIGGIJF3UXGQEGCGAN22ENQ',
#        'AFWB5OYK5G6GUU6PRLCDBJTY5K6A', 'AE3335XF4PMHSXKTW5B7N7EALG3Q',
#        'AGMK2F7WVGER2O6LO6TJMAHYTB2A', 'AHNBASUOKRQ37WGJIHZ4W5LHGZQA',
#        'AGVHU2LEJ466Z6WIAGGJLGJQWN2Q', 'AGCEUKGYJQYNHXGTWRCCJRZH5JDA',
#        'AESI2BA4YODTHOSRFLJCSTAM6XDQ', 'AHX2B4DEER2QR3IU3CCNB3CWC6TA',
#        'AHQFRZY6AJTJCFTPTLKWQXMZUV6Q', 'AESMJHGG46YWWOZSNNOE74SRMHFA',
#        'AHMFD567A4DYUH73S62GPGOAMY4Q', 'AGVZIUJSKTPVH5FQLGD46NYLA63A',
#        'AHXG3LDD2HEQEFJPCI7LCCCWTK7A', 'AHCWI6QZIANCIAOA6ZXPJ5CKATOQ',
#        'AHGIDR4IJFS23Q4GTZ33FI5LYDSQ_1', 'AGLQET6T4ZX4C4UXTNEMYHIWLFHA',
#        'AFJN65QRNENSBQ54NOJF2XTV5JZA', 'AF3PBFOBATUFYBJMDEIBIHK52NSA',
#        'AF4BKLYINRY2QC6LLNMXBO43T35Q', 'AEYKTZXAWOPJG5MGGMKBLRJR6Q3A_2',
#        'AHBPSHEMHC3S5T24ZSAUATFMXLUQ', 'AF2BLE54TEMGZ546U763ZHZRXC4A',
#        'AHTG2F3FAPHSGNZYEAZQ6R3IH2NQ', 'AGN7BHEG6A24SQ7XZIRIIGWPQWDA',
#        'AG2A3QBD6XORIGLLRIAZXARJTOCA', 'AG54MM4KBSKTJ4J5YVN3UWB2BJ5Q',
#        'AG7HNLUTHS6AV34PDGWVXYBCN3BA', 'AGWF6BTLJVQQ2N2R5PKNJOLY65GQ',
#        'AEMJEAQU77F54G6IJPXQLRYJY5LA', 'AEAZSFHKEWYCOXNGQDH5FE4ZFABQ',
#        'AEOFWIA66ZGRSWVDH5LOSU7TLHGA', 'AGPYTSQA67QCVA6LBPUV6JOGRHHA',
#        'AGY5CMCUZSD72MF2ZFZPLDIL66RA', 'AH2FJDJDFU3NIZLBO7UYJNJJXXAQ',
#        'AGU5HARCZRIMMAG6JSNPDCTI2BMA', 'AHOETYTW24FWK46AC3YLCBJ4MVEA',
#        'AHALZ7AKVAVL7QEVBCI55JVLGXOQ', 'AGCGRRDVGAPEKYF2U6R75T7NBZ3Q',
#        'AFLWURYXY2FAAWNLBPN73LP2G3OA', 'AH5OTJDIHBG4SYLRYWKS7MR7NWUQ',
#        'AHCJ6ZHES27WXPOVUY2JDLXZCOWQ', 'AFM5H5EI56IPF4NAP6DXMWIGSGWQ',
#        'AHWHB3ZUBURAXBABADUCHJ2OPBHQ', 'AFIN7BPPIQE6GN3RXU5WPRWHFJPA',
#        'AEU64BW76A3GKMZAGLUZZORCMB7A', 'AF2MVJO6VY5GVDWTBUEHKVLI7OEA',
#        'AEPZKDW3NXSTWNAOENWTKGFOERBA', 'AHZZ3SRJZNF3NRKIAI32UF345O6Q',
#        'AHV6QCNBJNSGLATP56JAWJ3C4G2A', 'AEKOMA7S3ZEOMRNTKWQ3MRKLXI4Q',
#        'AGRH6IVDWDM6EALBXC4F3JCPEK2Q', 'AGYVC7KVHP2AWM7BDCEYNHFA6F3Q',
#        'AF33GMD4PP7S2CNOGJHZMUYTCOXA', 'AERNZBXHDAWTBGW5DPF254SRQANA',
#        'AHW24DJ7Z3ZULW3NHAQIG23CMTSQ', 'AG4D44BNNLUEZNG7COK2CNRYUHYQ',
#        'AEWWI5TKZXWECMOMEQ5XG7ZSOIIA', 'AGOLAGQV5HC2YVU4EMSVYDWFEXNQ',
#        'AGXMWJK3YL4SV5FJ27JEJZPZHRBA', 'AGCVCHQQIWAKCQYWH2WEU4G2IYSA',
#        'AH3X33BLLYI72F2KKSR4LVCAC44A', 'AFEILCLVJYNSEB5CXXFASDO3WK7Q',
#        'AHUDLOVXG6WRDVAHFMDLBS4X6RUQ', 'AGLGCQJ6R7DK2HOZRYGHMQ7D6BTA',
#        'AFTJ7XQN2EIELHARUBBL6Y7L65DA', 'AEMQQSGGEXIZ6GZTC26S6XWFALSA',
#        'AGNDVKVTCDMRUONHBUIKPICKOJGQ', 'AHACF622TSBJA56BGLUWKX7FJQLQ',
#        'AEX6II6Y6M5FHWDV45IBFQCLDPDA', 'AGZNRYRCY2FZPTNXTY3D4S3YLULA',
#        'AFA6RPDUHGFJTP4HNCSP4W5A4KFQ', 'AF6RTFII4XB2EGU2C3SYBIRGG4VQ',
#        'AH57EB2DKN2XI7MXRH4ENYUTLR5A', 'AHD57KXX5NLI7JWKWGHQWASYRMYQ',
#        'AGRZ5CPZB6AV33VQNVXNLDCNTXYA', 'AHBINLCYU4DBWUHZRFXMEATLU4SQ',
#        'AHPPX3NV2FSHEMKJVSFB23INOXFA', 'AHOW2XFEXE4DJ5ULYJ5HYDJFFUZQ',
#        'AGWBUKSCPNQRIL6AGTQETJK4W7ZA', 'AGRC3JDXRCSSQ6TOMEB66Y5ORIYA',
#        'AHVXB7OB3526HIBQGB3YHRA4M3IQ', 'AGONPCOSQR6DDBR5M2RDX655XKGQ',
#        'AHDHLL6NDQSPJFL2O6KWALQH7XMQ', 'AFWRIFAOR2NIIIGH54PNNGP4AXXA',
#        'AGS4277MQVOM6YK6IBX7FXC3CNCQ', 'AEGOTPW2YNGTIE7HV4QGMVFH7RGA',
#        'AE7MDKFOYFBG7IZ7SFT56UZNWHPQ', 'AEGTJSI4X2EZHAL5VWJV3RCJIO4A',
#        'AG3DIEGS4AH6273XRWFK4KFT64MA', 'AFDNVPMB44ZS5O2CSJTL47BI2QTQ',
#        'AEBL6QPNNEZPLI2W67LDHT4Y5AAQ', 'AGTQBZ473HTO6H2U63IJGZWJNRMQ',
#        'AHQGMYIMLKKAPVGC6U744J4ZBQDQ', 'AG5J27TEIH5TXYW6XIGGIZACBESA',
#        'AFB7QGOJXRTRRZ3SDOSIRCR66UQQ', 'AFUIOJSGPJX5LSDL3WS3HLCE54WA',
#        'AHDETQESQB33VZPJZ267WH7X4C4A', 'AGGWKLUXGVI55DV4OPQYHAYU4JJA',
#        'AGNB67I6WO36NDRWUTGJTAU5BYPA', 'AFFVAEVXTKEZZ6RAOEXCLWSB4ABQ',
#        'AFRHNQ7FMQORXEGI4WFRI6RROX2A', 'AGHS37QMFIKXFPK5IBEGK7FOPXSA',
#        'AFMAUN5DZBVNC5LTLDIDGY4AT3XQ', 'AH5S3J3FHQUEA7CS3QJ4CSR63I5Q',
#        'AFE2H3RSA7M3USDHXBQHUO3FEZXQ', 'AH6Z4ETGIWORDLJBRJL3JJYTB53A',
#        'AE4YB4AE5WZMIZHVUVRP3TXCK5QA', 'AFCPEVIISAND63SSD5CGYXPNPKQA',
#        'AFE6KL3HGEKB2PUZLA7TYDITAWHA', 'AEQKG4FNUB67X4JUBJRWT3ISVKDQ',
#        'AFVK3GS2AW2DPXX25FO4OGAYJV3A', 'AG25WKAMSWXOBRRTF4YJ6POT6J5Q',
#        'AERL7OIMUH7HUWWOE4JY2D6G7PEA', 'AGXNNDGBBN7K2RJQQW7UBR347SZA',
#        'AGT4N3Y3EMMJQZW3ULQILEVTRBQA', 'AHEJQ4CPSHAQNTHL4BCVCAPZ7YWA',
#        'AHR74CICPWZUNBHD55PYJDW7KALA', 'AGCVRCNB4FGVZI5N2Z7CLE5PUGNA',
#        'AH5HSMUMRJRDWBPFDQ6G3EAAOSFQ', 'AEMLNOBVEIFE56QMLS34PGXBUW3Q',
#        'AG3YTFU4HQS4SY6QGEXG32C3Q67A', 'AHUSGJTSWSBCP6YBKEKMXZXM22ZA',
#        'AEWU3S5THPVW2IU676EQN5D5FSFA', 'AGJ47ZNTEDZTJPOAQ265ESCSD4WQ',
#        'AFSJ3SUK5KDGNIAFLHKZS3ZMNR5Q', 'AHZGOBCCOTN4N6CJL5ROJH7GKNPQ',
#        'AFDARPZHKNSTYAB5OQC77NBDCY6A', 'AF4UB2PGVLHK45WF7I6OED36OQDA',
#        'AEMPZJNSZKOBERHZMOKDBZCKFAIA', 'AGZZXSMMS4WRHHJRBUJZI4FZDHKQ',
#        'AECMR6C5TKZDWOFVU4OLHCNVMUFQ', 'AEUVWJ3UQIA7EFCDBB2MONNO67MQ',
#        'AG2KIKQMTPQL2C3LR6GKD33TDQVA', 'AG7NOEAAE4HKOSN4PTAD7Y3TN3EA',
#        'AG2BRENMUQY2CDPDDBIDD4FNYAHA', 'AHP5VABVUZNE4DZRHTCW3XZ7IXSA',
#        'AEZS74RGFK7D7KOQPFKXBCEKOFDQ', 'AEUHQGE4QTUUEMI3GVL7T2VTPJRA',
#        'AGJWAZESYDYURVDSAMHKVAM2IBWQ', 'AEHTPCFFRZYADDJ6LUHMWN5R2PRA',
#        'AESSPAEIBMPBUE5V6WTYMJTWZUXQ', 'AE3UKETTR77J4LM2ZE4AEUC4L6KA',
#        'AFIQA2PGQRR5EVIKFSYHOQ575A4A', 'AFGL2GSK2VQLFAAXP4VHQGZMBLMA',
#        'AEQTJOZ2FQGNW674GY5WBKLYLQPQ', 'AHHOJCG7WGRFOXFL72HTS3QMZ27Q',
#        'AEHGRAMBYNA2LJU3TLOX4YYMGN2Q', 'AFP423WNLK7T3NGWPI76PUZJXVRA',
#        'AG52E2UOCZUHNXLAZMB2JQISNNMQ', 'AFJ53427YM3CP2YRGQURZNQB4AMQ',
#        'AEAT2QOOIXWFLBQESCVLAVXLK3RQ', 'AFRVKY6SU7KLE3MH4KLSPUUL66UA',
#        'AH3FCTCMOXMYVHKGZEUJY6ML5TLQ', 'AF7QLQBPONYKXNDZCH3RFHB26NWQ',
#        'AEXYLV5YOYWSLGG47VVECVURA7XQ', 'AE647AXNLY7Z2QEWUPYUPY7UO6WQ',
#        'AFB6YX635T424MJEJTGZFHSVDSPA', 'AEENCDY5YPETRNJ2UY3XJ6SLAE3A',
#        'AGZRJBODYLZYOXEQ3QSAFIY2MPQQ', 'AEYI3SKHSGY3RPFPSYQIERGYDTPQ',
#        'AFDYIK3FNPY2JFBQYUWC6GSBMIRQ_1', 'AFIVKURWIEZA4WMLSZR6NWU7D6WQ',
#        'AEJQXUH6SULRQEHFRPYKL26HMGRQ', 'AHHBAGQYRP4XWVCDF6LWHCGQHOQQ',
#        'AFBNJ4ELEUMGBTG5WWZX46CFI2LA', 'AHWM5TMF6V2RS6I2ZJYRKYOWMQSA',
#        'AFGYYDCFXEENRXCMDJWKJKJOIOLA', 'AHSV4TYSAX52BIHH7PLZRD44KZHA',
#        'AFIJOCX5QMHETR5FCMWZUPOLAZMQ', 'AEZY3WQ5CO4DOXRNJOWWXJYKCAXQ',
#        'AGA4RNHD7NDFBDBAFSDKIKPBEE6A', 'AGAMRDZKJ4UJTWML4UTDT3VLVTEA',
#        'AEI37P2K6YHKFLSOIOUKAURUY6JA', 'AFSYEOBTC3ULN3DGKABPFR6FIWQQ',
#        'AHUQMOWLZNKGKX5N62J4AAUDGBKA', 'AGN5KJZU3FYSKVWXWM66LXYWL5CQ',
#        'AFO4E4RVVDONLY6NVCZ5OS7RBJXA', 'AEO7G5XUNQHEFDS257FD4253ZVEQ',
#        'AGCZOUUASH2RJ4VI7YTGL6AJUWZA', 'AFOBFBXYPXAPV7XVDJNLZ3LUCXTQ',
#        'AEGZZHKCFJWSJBETFV2XU2NNXOUA', 'AGC3DXWZ5EF3HC6LCMEBUW7GNVJA',
#        'AE6TDCUOKCSCRL5ZHWKEL7QHOA3A', 'AEAXVFSE6HQTWP5RA65SLOATKU4Q',
#        'AEXGISIVX7WBUNI7UHHERVB3DF7Q', 'AFMKNVUMCUO2DVEEMX4VOW3NQHGA',
#        'AHWKMQEXHHOFNYLHMS3TCTKRKY5Q', 'AEOQEWKXLQVGBSVIETVGOQLG2BMA',
#        'AGBIU7SJZETBVKRHMASGPWAQBYUQ', 'AFL2WX4AKJNHSIRWN6ED5XB7DKVQ',
#        'AHIPBWK7765RY56QRM4OQNQNRGXA', 'AFA676CIMUEWTZ2XBYUQK6ZZVY5A',
#        'AEP4KJDGBH6XPJKFEHPYSAPUNDBQ', 'AGUTZC4GHLTGYHA3KBEDRF6MHB6A',
#        'AGVMU3ZRTWWL4I6XLIGNJCZ6EVNA', 'AEBJMIPXKTN3XIEQGJZR6EHZLTOA',
#        'AHPRJ4MJGT4RM5TCJTTBFAWL2RNQ', 'AEBQBBBBK3ITED6TRRFF6UPB73IQ',
#        'AFCPMQ67JWMIONPWU3FY2L7W3GNA', 'AHSACQHEYZ5WHHMXFYYX4MKFU3LA',
#        'AFVEN6S4C75FTRPKTLVYCQHXAQWA', 'AHHQMVOQSY4WOIU5AWA5AEAQPJ6Q',
#        'AE3JFX5GZYFAWX7RS2X3SXHPJUJQ', 'AF47GQSRXLSIZTGVQPFDBI4JW65Q',
#        'AGNOZ725JFL26UXHLUCAFIURIPLQ', 'AEDMJIOBXFZJRL7EH76N3APDS3TA',
#        'AHHKY6BWQPFXVB5HWOMCKLPY22WQ', 'AFVPY2H4WXYFY2Z27Z5SSM5TQECA',
#        'AG6FX4Q7FYULVJL3DUCHJRNPS6VQ', 'AF5IHYFFANVZEJFCQQ5OPDNVUHIA',
#        'AGNPGOP7QUBNIRE7G6F5WZAXCDQQ', 'AGSXLZUUHBTZWMEKBANMJMGC42JQ',
#        'AH4WPD5UUVJGONWDBWJKFXVTOXGA', 'AGVKHJUJJC46JBYKZKO32XHG2Z2Q',
#        'AGNGNADVSWHDJHIUVLOOJ4EUUUJA', 'AE3KLVXGZPANXE5XLXYKHTVAZ3FQ',
#        'AF2FNBSFPSCWJYL6X2GR47YOQRAA', 'AE4LTXTD5TUPPWFKDGRYWTPS7BRA',
#        'AHTTDWB3A7MFG5BSBUSQ6EOCEHNQ', 'AFTTZX22B5LGT3M5IV4GXGPF6TZQ',
#        'AGV2YW5B3SCKG6WV422CIITZOGRQ', 'AHUTFRK2HMZ3NXR7QCBUVZLNA4XA',
#        'AHYIBFHJNWCLEHYLUTAOYX7SM26Q', 'AH3BXW7KLIS2VAE56UXJS2NS7I5A',
#        'AGPQIYXWRIYKJXVCFGTIFNJB5PNQ', 'AFO4WKDHF3CPJREG4SXVAMVYA6UA',
#        'AFVOZ4UNUZKEQ7GTQ3IHQY7PZ5FA_1', 'AHHGE2PEVCLVIJ4UDPLR5XUM5NQQ',
#        'AG3WBLM2HAFAVG7MKCJXAX3DEB6A', 'AGNRUW4XS3XBA4O6TUTRVVOTPUSA',
#        'AFJL45ZWJGWT6LE4WZ65QACDDPKA', 'AELE3ZZJEQVY5DIUYIYMXQD4YWDA',
#        'AFBVYEPWXFUFOTLRSK4SDY22QJGQ', 'AEJGMK3WXPRQYWO34DUXORXUYMJA',
#        'AFFDOYDP3XPM2YZOU3427DIXSF2A', 'AENUFCFZD4UYC7N65YFC6FB5WZIQ',
#        'AFCRKIT2TWCTOLLONJS7MWWZ7JFQ', 'AEOX6BMEBEXAQA73AOCR27WRRN6Q',
#        'AF3DUJDIDHG4UQAXGTTNLZSSAAMQ', 'AFJ2UX5PRHZSFRVDPALAVATWX7EQ',
#        'AFSL3XUMIYHLK4OU3ELPCMJAXK4A', 'AEHJ6W3IGWCEJGQMOGRTSRHMCUNA',
#        'AELRWE7QQJRKDFHDQHVAODTF5FRA', 'AHMB4UDFITWAYYASIZ57XZYXMKPQ',
#        'AHVYIEHS6YIDD5LRIID5Y7PD7EXA', 'AFKG3VR37BWUB3ZFIVGFBM35UUVQ',
#        'AHHW3CCF7GGFJTLZNBASYOGDDTTA', 'AHOJ6ZX2BUDEKAIKBPSOMJNKRYTA',
#        'AEHZBUFEOW4TY3K4IYFFR5ZU5B3Q', 'AEW3WTHVEO6FTLLLJUEBRNQ22K6A',
#        'AEODMW6CD2LWJZMP33NVXULB6DUQ', 'AGMDIYGG6PNMALGHXBOBNF53STNA',
#        'AETEIFB3H7DPXN4MXWR6XLWVN3PQ', 'AH43P3VKK33CUOLSHWF2G6QIFXEQ',
#        'AHUICOMTULLFCXZKJM3ZOWJRY3CA', 'AHTLWVDXSMG5YMVMEIWWOU6XBZMA',
#        'AGWCUTAJVN4BOWKT5FLFRA4DDYSQ', 'AET7D7ZHOIFXLVTUTNTTKZ4XTMLA',
#        'AHKGHHWIAXJMT5JU4T2GZGCPYF5A', 'AFJBKPK5W56XWSNPQU2WW66ISWYQ',
#        'AF6DF6LDLVVSSEOSXMDPMJJVRCIQ', 'AFGCJIO7DNVCCZPG4KVMKKXVPJLQ',
#        'AG4MOIVOM5L3TWAC6HCELPCPNCBQ', 'AEQ7D7IDDUFNPOL4VDSXWZPIWKUQ',
#        'AH55ILESZBXBNEV6VFWIH3UGMJOQ', 'AHYBIW6MIF6BX76MN45UZKZWSOXA',
#        'AFKZESU3PTCQ2UVDBDSFVFTXBFNQ_1', 'AG7ZPUCKNZK2NBRNUVL53CTATQ6A',
#        'AEEVXEJYV4A5CPDDHK63IRSDTPOQ', 'AEV344R5X7ZYZGJ45Y5AZ77MHUHQ',
#        'AGC7FEG2OWFIEFUNSRLN5JZPCAQA', 'AH5U7H6FAWKDAVBCNVQE4BRSLC3Q',
#        'AFOP2GGGLKAZPB2ISKTYWGP4RZNQ', 'AGCZK74VWTPV33JIHPDNOE54LYZQ',
#        'AGO2XKG37RI44JCHAW2U2UVMSB6Q', 'AGFXY5HVXFJFJ2SJDGZL5YLGR6RA',
#        'AGMXSVEF47HBVFLSPV7DLNYX3PFA', 'AEGJWM6UQ4GG47ZFVIZDACJGI45A',
#        'AGW2OWIAC7RJ6BPNE4Y7ULFFGZMA', 'AEE2BXE6TZBE3HI2LFEHIN47DWVQ',
#        'AFUXEPQACEVGZP66BHG5QPLS6WEQ', 'AE5R4AFGAJCL2XKFXU5XUSNOQSLQ',
#        'AHVTDQOUXKSP4KSJEKQBOF7TO4OQ', 'AFCG4NPG4WSBQP77RPYUS2FI4WBQ',
#        'AELD6DB2SLOC3Y26UL65RUFAEJDQ', 'AFJN5PUAJLTYWB5TEDK6QPEGJCJQ',
#        'AHKGUDFRBR2ANPQ6RTOFWNZA3T7A', 'AFHZZSTRFN7W2EFMR3KNYRVJANPA',
#        'AFAQAN6QJGIKXSW7R5VTGBOZ2UNQ', 'AFZTO5A5MT6WHKAQ6J4PKLZO7WLQ',
#        'AHQEBA7UEWG4TRTDWB2U2TITMBOQ', 'AHPXDR4M4552GWARMK6N3ZNI3WTA',
#        'AHDHUU6VI5LZMFQ6F6GKSIYWB2XQ', 'AHYKEWQ2L7YHRNHHGHMEBCLSE2BQ',
#        'AEVKSDMBQ23DVB4JRR5Q4ZPUPASQ', 'AF2LDA3IVYZSUATG4IEV64OPUTVA',
#        'AHAMVCCIEEQ753WZJQ5DOMXQBEDQ', 'AGZKLDUDYELPMHACIWTGAYSQHSSA',
#        'AFLEYJEKFADDXTLHXDL4KWLEU2NA', 'AFKFVAYA4CMNNMU6GR5GDKN4SB2A',
#        'AHIAY72GGXNMA5UFC7CLRORBCN5A', 'AGMR56SIQOZRYWBPSSXMCEC2SZVA',
#        'AFBE2UOACAYKHQ4KXR2JSDZKKD3A', 'AFVLZ5PK7IRJ4RLUC5BWCJTLF6EQ',
#        'AEAH2WGWOCEEMIU2NVZUVDT3COVA', 'AEGW2TKTQU35QLJR2PUZQARSIGWQ',
#        'AHQMDCDYOWBXN3IT4HCR6WWBSVNA', 'AGABMYCQQTVWDLZKR2ANY5K5PFLA',
#        'AH3QSXCLMLSSOAONGJJXDH5PCZQA', 'AGI2DGPYBLDOMDEFOFB2Y34CYMMA',
#        'AGBG3KK74IKWJNQVMQAGVBWJ7FAQ', 'AFPPNF3RSFMMNC5UAM6V4B475MBQ',
#        'AFYSGUD7WIXJU4Z4YGWPLOJWVTDA', 'AG2NRSDQTTI3QAFNJOSKEJL6A7WA',
#        'AFOVVZQGA6LXDUIJUQI4OE3AD5YQ', 'AHO3AHRQQ6PYRQUNUTTOBDZFLEJA',
#        'AFVL5CL63EUUNDO3QPHQQZPK7FJA', 'AEN2YWRB4OSPIEXAK7C3U5L3OPMA',
#        'AFJZAILRJPGX4FOJF2C2DXTFVE4A', 'AFJBOS7A5IEFZAYR2NB7HQ2OZBWQ',
#        'AFWTG5KZEI542BTLSOT3I7SGFMFA', 'AFTSM26TTLVW7VGJFWLPGV3CYX5Q',
#        'AHJGOVXWEV57QYKHIJZVHA5S5DBQ', 'AGTU4ZWZKYB35FXPND7RYMMAIP3A',
#        'AGGBH6ACHD4HFHHLAVGGQV6NRKBQ', 'AEOJWMWHWXTDHZ2X6TLFNHCOEH4Q',
#        'AEJMMXJCLTRMLAZS5ZJJRDHS7DTA', 'AHPG65LKS3QKRWDUWAKZNLEK5RZQ_1',
#        'AHC44BEFLJUHBMXM45BRMHEX7ZVQ', 'AFNCHMAKUAJOGVCKOA4XGLINHPDQ',
#        'AEZG2W4TRMMNFFAWS2BPQE676K4Q', 'AH6JLX5SJSUOJBBT6RRE2RDXIG6A',
#        'AG477X63NHBGNBH4JNG54QRW2QOQ', 'AEQTHZRWFWBTBZYLJG6EWPWYS3HA',
#        'AFRMOOG7VG4WSGTOQCQMGLIGC5LA_1', 'AFQPQMQ7UYR5Z5Z5WPJINPRWUWIQ',
#        'AEFDPPPB26TX6DH3GPM45NK2T5FA', 'AGP5PVK5Z2OKNJEGRNWSKAUWBGYA',
#        'AFLLPNLD4RUX642HDT5PH6T47AIA', 'AE34WLBH5CYAFHVPWCLQ6CBO3XSA',
#        'AFWWE5JBRRI4EIREYDQNURVMB3DQ', 'AG7WXYJR3N3IOL7NX6QUZJUPBVDA',
#        'AGSVNZDZNPCMXG5DEFXMZNRH2LCQ', 'AFYUZCYQ3DDCJBRBRMCCWO4VW2OA',
#        'AERILQFSHC5MF2MTEO7HGHFB72XQ', 'AG2JZI7U2WYEN7BQPK5L6MGA3B5A',
#        'AFH76XV2LGPF6FU2E7K26SQWXVTQ', 'AGZK6O6J5NQJCONZ3TZ6GHOR27UQ',
#        'AHAXGNEXTL3NFP3CIN7Z6UOECQ5A', 'AF5NY3AH3X4FZO43XIRZISEBWBRQ',
#        'AGZADXR7E4OHD6WVQSDNNG455WQA', 'AGS54P6RL7SIWF7R4L3OEAPST2TQ',
#        'AEUCNFPSBPIQE4PHDLGJTUFZDCPQ', 'AEWHLGO6FWZ4ZO7N6TX7I2FYO6EA',
#        'AE3SVP2P5GYCZU3Y7QVCJNYFY6JQ', 'AGHPLWV2JSOLYNY3WXMSAWFIQXCQ',
#        'AHJH4533YOYFU5OHTBYMITNU2PNA', 'AFJCZBSSHOLFPAQ72QFWEVCNGOJQ',
#        'AFBB4KLHM6GBLAEWLFK5TZLEJUJA', 'AHLQVJPH73V2UVWJCRLAXXFKOGLQ',
#        'AG63W2BMC4HRP76AMS36AYY64AHA', 'AEBI77VFI4X26BZNP5EFNKW7JETA',
#        'AHQYPIENJQJUM3KI34WDI4KK7CJA', 'AE46PO7VRKBNHUKKZDNB2C4WAOMA',
#        'AFD5HRDFOBWATRHJ4BOMLN62UKTA', 'AGMZO7NPGHYPLCOCLMQEDGKNCHVA',
#        'AHM2SQFLXBSFHGRX7ODEO53A4ZAA', 'AGNBCBF57EU5X3W2M2JCSOFNUWWA',
#        'AHKHMEAVC5FTV6VNLMVSKC7VVKAQ', 'AE5YGSWQJFOVOQBX7TVX3GYBPIGQ',
#        'AFEDDBBG5QGBD75VUJ2NKKK6E7DA', 'AG4TRGDHYIBT4CH63VJYM5IOAMTQ',
#        'AF4DG5BLYC7DTEIR6PFK5CDMBZ2A', 'AFDXLEJPM4ADJ5QBSU3KTMQ6HI5A',
#        'AHO36PJZJRKHHEC52KMDJ4ZL2JBA', 'AEV2EK3XYOTX4WYO4A6CT2AA4DUA',
#        'AFUNUNBPGAML3VCYIANGF3FIH57Q'], dtype=object)

# %%
df_PCA_single_user_check = final_df_user_PCA[final_df_user_PCA['user_ID']=='AGGS22XG63AQTYBR3APBQA25HAYQ']
df_PCA_single_user_check
# Out:
#       rating                                  review_title
# 175        3  Does not hold a lot of hair, even though ...  \
# 2347       5                                       Love it
#
#                                             text_review user_images
# 175   Does not hold a lot of hair, even though the d...          []  \
# 2347  When the item arrived to my house and I was ab...          []
#
#       product_ID   parent_ID                       user_ID
# 175   B000X20Y4C  B000X20Y4C  AGGS22XG63AQTYBR3APBQA25HAYQ  \
# 2347  B00DPNKDR4  B0CDNZ7F2V  AGGS22XG63AQTYBR3APBQA25HAYQ
#
#                     timestamp  helpful_review_vote
# 175   2016-04-29 02:18:14.000                    2  \
# 2347  2016-04-29 00:54:59.000                    8
#
#       user_purchase_verification  ...   dim_290   dim_291   dim_292   dim_293
# 175                            1  ... -0.005839 -0.046676 -0.107566  0.079659  \
# 2347                           1  ...  0.069342  0.064106 -0.045113 -0.067857
#
#        dim_294   dim_295   dim_296   dim_297   dim_298   dim_299
# 175   0.033594  0.008136 -0.009612 -0.064018 -0.000251  0.001041
# 2347 -0.002163 -0.066787 -0.015612  0.014508 -0.040077  0.008095
#
# [2 rows x 313 columns]

# %% [markdown]
# Analyse recommended product

# %%
product_ids_to_filter = ['B00XFGNPE4', 'B01N41MYDC','B08GWZKPPL','B0B8Q3WTGP','B00069Q306']  # List of product IDs you want to filter
filtered_df = final_df_user_PCA[final_df_user_PCA['product_ID'].isin(product_ids_to_filter)]
filtered_df
# Out:
#        rating                                       review_title
# 8375        4               Epil Stop 'n Spray -- worked for me!  \
# 22425       5  i finally found a great non-toxic styling prod...
# 39088       5                          Lightweight, Works Great!
# 43411       2                                       Disappointed
# 49737       3              Horrible chemical smell when it heats
#
#                                              text_review
# 8375   After reading all the negative reviews, I wasn...  \
# 22425  I rarely use hair products, because a) I don't...
# 39088  I have naturally curly hair and blow dry it st...
# 43411  I was disappointed in this pair of cuticle cli...
# 49737  What I hate most about certain products is tha...
#
#                                              user_images  product_ID
# 8375                                                  []  B00069Q306  \
# 22425                                                 []  B00XFGNPE4
# 39088  [{'small_image_url': 'https://m.media-amazon.c...  B0B8Q3WTGP
# 43411                                                 []  B01N41MYDC
# 49737                                                 []  B08GWZKPPL
#
#         parent_ID                       user_ID                timestamp
# 8375   B00069Q306  AFIQ3YH27NICN4VXZ5C32K5S75IA  2007-05-16 19:06:02.000  \
# 22425  B00XFGNPE4  AFXIGVQQTHA3WEZNZZ73MNI6XZQA  2015-07-26 12:36:52.000
# 39088  B0B8Q3WTGP  AEITAF3YU6VVHFTOZZLPRFBLJE4A  2022-08-29 12:33:13.546
# 43411  B01N41MYDC  AGWADILSGQN3BRNWRRYCHDXTJOKQ  2017-04-26 17:38:21.000
# 49737  B08GWZKPPL  AFWUV4IQC7OFBDAXTPNIKGX5VXDA  2020-12-11 02:20:18.437
#
#        helpful_review_vote  user_purchase_verification  ...   dim_290
# 8375                     5                           0  ... -0.092526  \
# 22425                    0                           0  ... -0.040314
# 39088                    0                           0  ...  0.062836
# 43411                    0                           1  ... -0.083816
# 49737                    0                           1  ... -0.006793
#
#         dim_291   dim_292   dim_293   dim_294   dim_295   dim_296   dim_297
# 8375  -0.046310 -0.027638  0.010680 -0.064729  0.015496 -0.007137 -0.024726  \
# 22425  0.013792  0.004826 -0.162115 -0.019986 -0.076660  0.069831  0.072245
# 39088 -0.031361 -0.068780 -0.071060 -0.037476 -0.036980  0.009345  0.015377
# 43411  0.046867  0.032366 -0.120519  0.104655  0.002889 -0.013910 -0.004298
# 49737 -0.011986 -0.045659 -0.059339 -0.024505  0.078402  0.060712  0.020307
#
#         dim_298   dim_299
# 8375  -0.068805  0.013464
# 22425  0.011234  0.037644
# 39088 -0.003733  0.005879
# 43411  0.036815 -0.027696
# 49737  0.023315 -0.052604
#
# [5 rows x 313 columns]

# %%
pd.set_option('display.max_colwidth', None)

# Display the cleaned_text column
print(filtered_df['cleaned_text'])
# Out:
# 8375                                                          after reading all the negative reviews, i wasnt expecting epil stop n spray to be very effective. boy, was i surprised.i did not have to spray it on multiple times to remove hair. one layer worked fine. i let it set in for about 10 minutes, applied a reasonable amount of pressure during the removal process and all the hair came off!many people have reported that it burned or irritated their skin. not so in my case. the only complaint i have is that the spray really does smell. but so does nair. no big deal.this actually worked better than nair and most of the hair removal products ive used.i dont know how effective the rollon or wipes are, but after seeing how well the spray worked, i just might try those too.
# 22425                                                                                                                                                       i rarely use hair products, because a i dont know how to use them, b i find them irritating, and c most of my favorite natural hair care brands dont really make anything that would work for me. however, i recently received a sample of this so i thought i would try it. i have mediumshort layered hair. while it was wet, i warmed up a small amount of paste in my hands and then wiped in through my hair. my hair dried in pretty waves, with no hardness or stickiness. later in the day, i brushed it out and my hair was soft and fluffy in a good way. i think i finally found a hair product that works for me this stuff is great!
# 39088                                                                                                                           i have naturally curly hair and blow dry it straight a few times a week. i was excited to try this argan infused brush to see what it would do to my hair.it is very lightweight to hold and has a comfortable grip. at first i wasnt sure if it would work, because the bristles arent very thick and didnt feel like they would hold my hair around the brush. much to my surprise, the brush actually worked fantastic. my hair is very straight and doesnt have as much frizz. i also like that the brush has holes by the bristles so the air can flow through freely.i would highly recommend this quality brush to anyone who blow drys their hair on a regular basis.
# 43411    i was disappointed in this pair of cuticle clippers. perhaps the issue is just with the pair i received, but they stick during use, requiring me to manipulate them with my spare hand to get the blades unstuck something that can be difficult, awkward, or impossible to do, depending on which finger you are attending to. and although the blades seem sharp, i found that they didnt cut cleanly or completely, and i had to pull at them to get them to release the snippet i was trying to cut, whether it was a cuticle or a piece of dry skin on the side of the nail. after using them, i felt that my hands were raggedy from little pieces of dried skincuticle that were left behind, making them feel rough. im not impressed at all and would not buy them again or recommend them.
# 49737                                                                                      what i hate most about certain products is that strong chemical smell and offgassing of things i need to use in the house. that is what happened when i used this product for the first time. it does heat very quickly, but the smell was horrible. i dont think this is ceramic, and if it is then its covered in a ton of toxic chemicals. i used it anyway on my hair and despite being really hot, the waves were not very pronounced. ive been letting it offgas for 15 minutes with the fan on and it still smells awful so i will be returning it for a higher quality product. the next one i try will be a ceramic one that you squeeze together, versus the one you pry apart and snaps onto your hair.
# Name: cleaned_text, dtype: object

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# * To classify customer reviews into sentiment categories, such as positive, neutral, or negative.
# * Fine-tune BERT (Optional):
#
# Train a BERT-based model on your labeled sentiment data (e.g., reviews with labels like "positive," "negative").
# This improves sentiment prediction accuracy for domain-specific language.
#
# * Direct Embedding-Based Classification:
#
# Alternatively, use pre-trained embeddings and train a simple classifier (e.g., logistic regression) on top.
#
# * Output:
#
# Predict the sentiment for each review and quantify overall customer satisfaction.
